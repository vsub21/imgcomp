# %%
# import os
# repo_path = 'fast-pixel-cnn'
# if not os.path.exists(os.path.join(os.getcwd(), repo_path)):
#   !git clone https://github.com/vsub21/imgcomp.git

# %%
import zipfile

local_zip = 'fast-pixel-cnn-mod.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('fast-pixel-cnn-mod')
zip_ref.close()

# %%
# go here and get direct dl link: https://www.dropbox.com/s/we5cltujdlhuxr8/pxpp.zip
# !wget -O pxpp.zip https://uc113f1b6e63f3f8399e224464ec.dl.dropboxusercontent.com/cd/0/get/AgHflUFwXH5GYKW1aVgXdTlRNQctD_LdNcqpUqr799SNrDdFKD2Ep_9Vi37MV9fiBdIVj-EkoZ3c1NvRBLXMZU8vbe_KU_7GXtD6L_4zsmyFUiFKlsS9o6AHR5nvQPp65aY/file?_download_id=7494433901997709054687733227130830976885359209909207041428629489&_notify_domain=www.dropbox.com&dl=1
# Out:
# --2019-05-02 06:09:01--  https://uc113f1b6e63f3f8399e224464ec.dl.dropboxusercontent.com/cd/0/get/AgHflUFwXH5GYKW1aVgXdTlRNQctD_LdNcqpUqr799SNrDdFKD2Ep_9Vi37MV9fiBdIVj-EkoZ3c1NvRBLXMZU8vbe_KU_7GXtD6L_4zsmyFUiFKlsS9o6AHR5nvQPp65aY/file?_download_id=7494433901997709054687733227130830976885359209909207041428629489
# Resolving uc113f1b6e63f3f8399e224464ec.dl.dropboxusercontent.com (uc113f1b6e63f3f8399e224464ec.dl.dropboxusercontent.com)... 162.125.80.6, 2620:100:6030:6::a27d:5006
# Connecting to uc113f1b6e63f3f8399e224464ec.dl.dropboxusercontent.com (uc113f1b6e63f3f8399e224464ec.dl.dropboxusercontent.com)|162.125.80.6|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 683321117 (652M) [application/binary]
# Saving to: ‘pxpp.zip’
#
# pxpp.zip            100%[===================>] 651.67M  69.3MB/s    in 10s
#
# 2019-05-02 06:09:17 (62.4 MB/s) - ‘pxpp.zip’ saved [683321117/683321117]

# %%
import zipfile

local_zip = 'pxpp.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('pxpp')
zip_ref.close()

# %%
# !mkdir generated_images

# %%
# # Generate images
# !CUDA_VISIBLE_DEVICES=0 python fast-pixel-cnn/generate.py --checkpoint=fast-pixel-cnn/pxpp/params_cifar.ckpt --save_dir=generated_images

# %%
# !CUDA_VISIBLE_DEVICES=0 python fast-pixel-cnn-mod/fast-pixel-cnn-mod/fast_pixel_cnn_pp/test_components.py
# Out:
# WARNING:tensorflow:From /usr/lib/python3.6/contextlib.py:60: TensorFlowTestCase.test_session (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `self.session()` or `self.cached_session()` instead.
# 2019-05-02 06:30:06.660864: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300000000 Hz
# 2019-05-02 06:30:06.661241: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x1c0c260 executing computations on platform Host. Devices:
# 2019-05-02 06:30:06.661280: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): <undefined>, <undefined>
# 2019-05-02 06:30:06.898121: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# ...

# %%
# Out:
#   File "<ipython-input-7-f6fe024d3ee6>", line 1
#     from fast-pixel-cnn.fast_pixel_cnn_pp.nn import *
#              ^
# SyntaxError: invalid syntax
